# %% [markdown]
# # AlexNet
#
# - [paper](http://www.cs.toronto.edu/~fritz/absps/imagenet.pdf)
#
# - [imagenet data(2012)](http://image-net.org/challenges/LSVRC/2012/index#task)
#
# - [code](https://pytorch.org/docs/0.4.0/_modules/torchvision/models/alexnet.html)
#
# - Model architecture
# ![model_architecture](https://cv-tricks.com/wp-content/uploads/2017/03/xalexnet_small-1.png.pagespeed.ic.u_mv-jhXMI.webp)

# %% [markdown]
# ### Naive Version
# CONV_1 - POOL_1 - CONV_2 - POOL_2 - CONV_3 - CONV_4 - CONV_5 - POOL_3 - FC1 - FC2 - FC3 (->SOFTMAX)

# %% [markdown]
# ### detailed
# CONV_1(ReLU) - POOL_1 - CONV_2(ReLU) - POOL_2 - CONV_3(ReLU) - CONV_4(ReLU) - CONV_5(ReLU) - POOL_3 -(Flatten) FC1(ReLU) - FC2(ReLU) - FC3(->SOFTMAX)

# %%
from IPython.display import Image
 
Image("image1.jpg")

# %%
Image("image2.jpg")

# %%
Image("image3.jpg")

# %% [markdown]
# # Q.1 fill in the '????' & 'TODO'

# %% [markdown]
# ### Layer 1 is a Convolution Layer_1
#
# - **Input Image size**     224 x 224 x 3 -> 227 x 227 x 3
#
# - **Number of filters**   96
#
# - **Filter size** 11 x 11 x 3
#
# - **Stride** 4
#
# - **Layer 1 Output**  55 x 55 x 96 (because of stride 4)

# %%
(227-11)/4 + 1 # 55
# Out:
# 55.0

# %%
## TODO ##

######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Conv_1 = (11*11*3) * 96 + 96  # 34944
print(Conv_1)
'''last 96 for Bias'''
# Out:
# 34944
# 'last 96 for Bias'

# %% [markdown]
# ### Layer 2 is a Max Pooling_1 Followed by Convolution_1
#
# - **Input**  55 x 55 x 96
#
# - **Max pooling**
#
# - **Pooling size**(overlapping) 3 x 3
#
# - **Stride** 2
#
# - **Layer 2 Output** 27 x 27 x 96 #(55-3)/2 +1 = 27

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Max_pool_1 = 0  #pooling, stride, padding은 hyper parameter이므로 계산x
print(Max_pool_1)
# Out:
# 0

# %% [markdown]
# ### Layer 3 is a a Convolution Layer_2
#
# - **Input**  27 x 27 x 96
#
# - **Number of filters**  256
#
# - **Filter size**  5 x 5 x 96
#
# - **Stride** 1
#
# - **padding** 2
#
# - **Layer 3 Output** 27 x 27 x 256 #(27+2x2-5)/1 +1 = 27

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Conv_2 = (5*5*96)*256 + 256 #614,656
print(Conv_2)
# Out:
# 614656

# %% [markdown]
# ### Layer 4 is a Max Pooling_2 Followed by Convolution_2
#
# - **Input**  27 x 27 x 256
#
# - **Max pooling**
#
# - **Pooling size**(overlapping) 3 x 3
#
# - **Stride** 2
#
# - **Layer 4 Output** 13 x 13 x 256 #(27-3)/2 +1 = 13

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Max_pool_2 = 0
print(Max_pool_2)
# Out:
# 0

# %% [markdown]
# ### Layer 5 is a a Convolution Layer_3
#
# - **Input** 13 x 13 x 256
#
# - **Number of filters**  384
#
# - **Filter size**  3 x 3 x 256 #inputsize가 13x13x256이므로!
#
# - **Stride** 1
#
# - **padding** 1
#
# - **Layer 5 Output** 13 x 13 x 384 #(13+2x1-3)/1 + 1 = 13

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################
Conv_3 = (3*3*256) * 384 + 384 # 885120
print(Conv_3)
# Out:
# 885120

# %% [markdown]
# ### Layer 6 is  a Convolution Layer_4
#
# - **Input**  13 x 13 x 384
#
# - **Number of filters**  384
#
# - **Filter size**  3 x 3 x 384
#
# - **Stride** 1
#
# - **padding** 1
#
# - **Layer 6 Output** 13 x 13 x 384 # (13+2x1-3)/1 + 1 = 13

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################
Conv_4 = (3*3*384)*384 + 384 #1327488
print(Conv_4)
# Out:
# 1327488

# %% [markdown]
# ### Layer 7 is a Convolution Layer_5
#
# - **Input**  13 x 13 x 384
#
# - **Number of filters**  256
#
# - **Filter size**  3 x 3 x 384
#
# - **Stride** 1
#
# - **padding** 1
#
# - **Layer 7 Output** 13 x 13 x 256 # (13+2x1-3)/1+1 = 13

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################
Conv_5 = (3*3*384)*256 + 256 #884,992
print(Conv_5)
# Out:
# 884992

# %% [markdown]
# ### Layer 8 is a Max Pooling_3 Followed by Convolution_5
#
# - **Input**  13 x 13 x 256
#
# - **Max pooling**
#
# - **Pooling size**(overlapping) 3 x 3
#
# - **Stride** 2
#
# - **Layer 8 Output** 6 x 6x x 256 # (13-3)/2 + 1 = 6

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################

Max_pool_3 = 0

# %% [markdown]
# ### Layer 9 is a Fully_Connected layer_1
#
# - **input** 6 x 6 x 256
#
# - **flatten** 9216
#
# - **output size** (N,flatten) x (flatten,4096) -> (N,4096)
#
# - **N** Number of input data

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################

FC1 = (6*6*256)*4096 + 4096 # 37,752,832
print(FC1)
# Out:
# 37752832

# %% [markdown]
# ### Layer 10 is a Fully_Connected layer_2
#
# - **input** (N,4096)
#
# - **output size** (N,4096) x (4096,4096) -> (N,4096)
#
# - **N** Number of input data

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################

FC2 = (4096*4096) + 4096 #16,781,312
print(FC2)
# Out:
# 16781312

# %% [markdown]
# ### Layer 11 is a Fully_Connected layer_3
#
# - **input** (N,4096)
#
# - **output size** (N,4096) x (4096,Num_classes) ->(N,1000)
#
# - **N** Number of input data
#
# - **Num_classes** Number of labels

# %%
## TODO 

######################################################
#  Calculate the number of parameters in this layer  #
######################################################

FC3 = (4096*1000) + 1000 #4,097,000
print(FC3)
# Out:
# 4097000
